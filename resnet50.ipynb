# %% [markdown]
# # 人脸识别比赛

# %% [markdown]
# ### 数据集
#
# 1、上传zip格式压缩的数据集压缩包
#
# 2、运行`! unzip dataset.zip`
#
# 3、按上面的方法上传test.zip
#
# 4、将数据集放置在根目录下，与work目录同级

# %%
# %matplotlib inline
import torch
import time
from torch import nn, optim
from torch.utils.data import Dataset, DataLoader
import torchvision
from torchvision.datasets import ImageFolder
from torchvision import transforms
from torchvision import models
import os  

import sys
sys.path.append("..") 
# import d2lzh_pytorch as d2l

device = torch.device('cuda:2' if torch.cuda.is_available() else 'cpu')

# %%
def load_data_face(batch_size):
    transform = torchvision.transforms.Compose([
       # torchvision.transforms.Grayscale(num_output_channels=1), # 彩色图像转灰度图像num_output_channels默认1
        torchvision.transforms.RandomHorizontalFlip(),
        torchvision.transforms.Resize([330,330]),
        torchvision.transforms.CenterCrop([224, 224]),
        
        torchvision.transforms.ToTensor()
    ])
    train_imgs = torchvision.datasets.ImageFolder('./dataset/train', transform=transform)
    test_imgs = torchvision.datasets.ImageFolder('./dataset/test', transform=transform)
    train_iter = torch.utils.data.DataLoader(train_imgs, batch_size=batch_size, shuffle=True, num_workers=4)
    test_iter = torch.utils.data.DataLoader(test_imgs, batch_size=batch_size, shuffle=False, num_workers=4)

    return train_iter, test_iter

# %%
batch_size = 32
# 如出现“out of memory”的报错信息，可减小batch_size或resize
train_iter, test_iter = load_data_face(batch_size)

# %%
# 获取并保存人名和索引的对应关系，用于测试过程中将索引映射为人名
import pickle
transform = torchvision.transforms.Compose([
    #torchvision.transforms.Grayscale(num_output_channels=1), # 彩色图像转灰度图像num_output_channels默认1
    torchvision.transforms.RandomHorizontalFlip(),
    torchvision.transforms.Resize([330,330]),
    torchvision.transforms.CenterCrop([224, 224]),
    torchvision.transforms.ToTensor()
])
test_imgs = torchvision.datasets.ImageFolder('./dataset/test', transform=transform)
label = test_imgs.class_to_idx
label = {value:key for key, value in label.items()}
# print(len(label))
# 写入文件
label_hal = open('label.pkl', 'wb')
s = pickle.dumps(label)
label_hal.write(s)
label_hal.close()

# %%
#修改net，pretrained，正则化

# %%
net=models.resnet50(pretrained=True)
# print(net)
net.fc = nn.Sequential(
                       nn.ReLU(),
                       nn.Dropout(0.6),
                       nn.Linear(2048, 311)
)

# %% [markdown]
# ### 训练

# %%
def evaluate_accuracy(data_iter, net, device=None):
    if device is None and isinstance(net, torch.nn.Module):
        # 如果没指定device就使用net的device
        device = list(net.parameters())[0].device 
    acc_sum, n = 0.0, 0
    with torch.no_grad():
        for X, y in data_iter:
            if isinstance(net, torch.nn.Module):
                net.eval() # 评估模式, 这会关闭dropout
                acc_sum += (net(X.to(device)).argmax(dim=1) == y.to(device)).float().sum().cpu().item()
                net.train() # 改回训练模式
            else: # 自定义的模型, 3.13节之后不会用到, 不考虑GPU
                if('is_training' in net.__code__.co_varnames): # 如果有is_training这个参数
                    # 将is_training设置成False
                    acc_sum += (net(X, is_training=False).argmax(dim=1) == y).float().sum().item() 
                else:
                    acc_sum += (net(X).argmax(dim=1) == y).float().sum().item() 
            n += y.shape[0]
    return acc_sum / n

# %%
train_acc_list = []
test_acc_list = []
def train_ch5(net, train_iter, test_iter, batch_size, optimizer, device, num_epochs):
    net = net.to(device)
    print("training on ", device)
    loss = torch.nn.CrossEntropyLoss()
    for epoch in range(num_epochs):
        train_l_sum, train_acc_sum, n, batch_count, start = 0.0, 0.0, 0, 0, time.time()
        for X, y in train_iter:
            X = X.to(device)
            y = y.to(device)
            y_hat = net(X)
            l = loss(y_hat, y)
            optimizer.zero_grad()
            l.backward()
            optimizer.step()
            train_l_sum += l.cpu().item()
            train_acc_sum += (y_hat.argmax(dim=1) == y).sum().cpu().item()
            n += y.shape[0]
            batch_count += 1
#         train_iter,test_iter1 = load_data_face(batch_size)
        test_acc = evaluate_accuracy(test_iter, net)
        train_acc_list.append(train_acc_sum / n)
        test_acc_list.append(test_acc)
        print('epoch %d, loss %.4f, train acc %.3f, test acc %.3f, time %.1f sec'
              % (epoch + 1, train_l_sum / batch_count, train_acc_sum / n, test_acc, time.time() - start))

# %%
lr, num_epochs = 0.01,4
optimizer = torch.optim.SGD(net.parameters(), lr=lr, momentum=0.9,weight_decay=1e-4)
train_ch5(net, train_iter, test_iter, batch_size, optimizer, device, num_epochs)
# Out:
# training on  cuda:2
# epoch 1, loss 0.7742, train acc 0.815, test acc 0.661, time 31.4 sec
# epoch 2, loss 0.6757, train acc 0.829, test acc 0.669, time 30.0 sec
# epoch 3, loss 0.4927, train acc 0.878, test acc 0.741, time 29.8 sec
# epoch 4, loss 0.3249, train acc 0.922, test acc 0.803, time 30.2 sec

# %%
lr, num_epochs = 0.001,5
optimizer = torch.optim.SGD(net.parameters(), lr=lr, momentum=0.5,weight_decay=1e-4)
train_ch5(net, train_iter, test_iter, batch_size, optimizer, device, num_epochs)
# Out:
# training on  cuda:2
# epoch 1, loss 1.0158, train acc 0.763, test acc 0.697, time 28.1 sec
# epoch 2, loss 0.8901, train acc 0.800, test acc 0.724, time 27.7 sec
# epoch 3, loss 0.8476, train acc 0.811, test acc 0.735, time 28.4 sec
# epoch 4, loss 0.7879, train acc 0.822, test acc 0.749, time 27.9 sec
# epoch 5, loss 0.7773, train acc 0.832, test acc 0.763, time 28.1 sec

# %%
lr, num_epochs = 0.0005,5
optimizer = torch.optim.SGD(net.parameters(), lr=lr, momentum=0.9,weight_decay=1e-4)
train_ch5(net, train_iter, test_iter, batch_size, optimizer, device, num_epochs)
# Out:
# training on  cuda:2
# epoch 1, loss 0.7255, train acc 0.846, test acc 0.772, time 29.5 sec
# epoch 2, loss 0.6788, train acc 0.864, test acc 0.784, time 30.3 sec
# epoch 3, loss 0.6229, train acc 0.877, test acc 0.784, time 30.2 sec
# epoch 4, loss 0.5861, train acc 0.880, test acc 0.793, time 30.5 sec
# epoch 5, loss 0.5545, train acc 0.899, test acc 0.799, time 31.6 sec

# %%
net.parameters()
# Out:
# <generator object Module.parameters at 0x7f5dcc20d570>

# %%
# 自己加个画图
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
x = np.arange(1, len(train_acc_list)+1, 1)
y1 = np.array(train_acc_list)
y2 = np.array(test_acc_list)
plt.plot(x, y1, label="train")
plt.plot(x, y2, linestyle = "--", label="test")
plt.xlabel("x")
plt.ylabel("y")
plt.title('train & test')
plt.legend()
plt.show()

# %% [markdown]
# ### 保存模型

# %%
torch.save(net, './resnet50.pkl')

# %% [markdown]
# # 生成识别结果文件测试

# %%
# 读取训练好的模型
model = torch.load('./resnet50.pkl').eval()

# %%
# 获取本次训练的人名和索引的对应关系
label = {}
with open('label.pkl','rb') as file:
    label = pickle.loads(file.read())
# print(label)
# 测试集label对应关系
import pickle
label_answer = {}
with open('label_answer.pkl','rb') as file:
    label_answer = pickle.loads(file.read())
label_answer = {value:key for key, value in label_answer.items()}

# %%
# 加载测试数据（在test目录下）
from PIL import Image
import numpy as np

transform = torchvision.transforms.Compose([
#     torchvision.transforms.Grayscale(num_output_channels=1), # 彩色图像转灰度图像num_output_channels默认1
    torchvision.transforms.RandomHorizontalFlip(),
    torchvision.transforms.CenterCrop([224, 224]),
#     torchvision.transforms.Resize([224, 224]),
    torchvision.transforms.ToTensor()
])
# 生成测试结果文件
path = os.listdir('test')
r_d = {}
for f in path:
#     print('test/' + f)
    img = Image.open('test/' + f)
    test_imgs = transform(img).unsqueeze(0)
    test_imgs = test_imgs.to(device)
    y = model(test_imgs)
    pred = torch.argmax(y, dim = 1)
    r = label_answer[label[int(pred)]]
    r_d[int(f.strip('.jpg'))] = r
#     print(1)
# 写入结果文件
r_d = sorted(r_d.items(), key=lambda a:a[0])
r_d = dict(r_d)
ret = open("result.csv","w")
for key, value in r_d.items():
    print("%d,%s"%(key, value), file=ret)
ret.close()
# Out:
# test/1015.jpg
# 1
# test/102.jpg
# 1
# test/1026.jpg
# 1
# test/1035.jpg
# 1
# test/104.jpg
# 1
# test/1057.jpg
# 1
# test/1070.jpg
# 1
# test/1075.jpg
# 1
# test/1084.jpg
# 1
# test/1087.jpg
# 1
# test/1106.jpg
# 1
# test/1140.jpg
# 1
# test/1148.jpg
# 1
# test/1153.jpg
# 1
# test/1162.jpg
# 1
# test/1178.jpg
# 1
# test/1183.jpg
# 1
# test/1189.jpg
# 1
# test/1200.jpg
# 1
# test/125.jpg
# 1
# test/1267.jpg
# 1
# test/1269.jpg
# 1
# test/1284.jpg
# 1
# test/1286.jpg
# 1
# test/1314.jpg
# 1
# test/1334.jpg
# 1
# test/1336.jpg
# 1
# test/1351.jpg
# 1
# test/1384.jpg
# 1
# test/1409.jpg
# 1
# test/1420.jpg
# 1
# test/1422.jpg
# 1
# test/1429.jpg
# 1
# test/1465.jpg
# 1
# test/147.jpg
# 1
# test/1500.jpg
# 1
# test/1502.jpg
# 1
# test/1510.jpg
# 1
# test/1521.jpg
# 1
# test/1540.jpg
# 1
# test/1545.jpg
# 1
# test/1551.jpg
# 1
# test/1560.jpg
# 1
# test/157.jpg
# 1
# test/1572.jpg
# 1
# test/1577.jpg
# 1
# test/1580.jpg
# 1
# test/1582.jpg
# 1
# test/1587.jpg
# 1
# test/1592.jpg
# 1
# test/1595.jpg
# 1
# test/1599.jpg
# 1
# test/1608.jpg
# 1
# test/1617.jpg
# 1
# test/1624.jpg
# 1
# test/1639.jpg
# 1
# test/1645.jpg
# 1
# test/168.jpg
# 1
# test/1689.jpg
# 1
# test/1690.jpg
# 1
# test/17.jpg
# 1
# test/170.jpg
# 1
# test/1706.jpg
# 1
# test/1712.jpg
# 1
# test/1715.jpg
# 1
# test/1730.jpg
# 1
# test/1765.jpg
# 1
# test/1781.jpg
# 1
# test/1794.jpg
# 1
# test/1810.jpg
# 1
# test/1818.jpg
# 1
# test/1820.jpg
# 1
# test/1832.jpg
# 1
# test/1834.jpg
# 1
# test/1869.jpg
# 1
# test/1876.jpg
# 1
# test/1881.jpg
# 1
# test/1902.jpg
# 1
# test/1908.jpg
# 1
# test/191.jpg
# 1
# test/1929.jpg
# 1
# test/195.jpg
# 1
# test/1952.jpg
# 1
# test/1954.jpg
# 1
# test/1957.jpg
# 1
# test/196.jpg
# 1
# test/1970.jpg
# 1
# test/1971.jpg
# 1
# test/1976.jpg
# 1
# test/1982.jpg
# 1
# test/1985.jpg
# 1
# test/20.jpg
# 1
# test/203.jpg
# 1
# test/2033.jpg
# 1
# test/2036.jpg
# 1
# test/2040.jpg
# 1
# test/2043.jpg
# 1
# test/2066.jpg
# 1
# test/2071.jpg
# 1
# test/2080.jpg
# 1
# test/2093.jpg
# 1
# test/210.jpg
# 1
# test/2103.jpg
# 1
# test/2129.jpg
# 1
# test/2144.jpg
# 1
# test/2159.jpg
# 1
# test/2161.jpg
# 1
# test/2176.jpg
# 1
# test/2183.jpg
# 1
# test/222.jpg
# 1
# test/224.jpg
# 1
# test/2244.jpg
# 1
# test/2251.jpg
# 1
# test/226.jpg
# 1
# test/2270.jpg
# 1
# test/2274.jpg
# 1
# test/2289.jpg
# 1
# test/229.jpg
# 1
# test/2298.jpg
# 1
# test/2306.jpg
# 1
# test/2314.jpg
# 1
# test/2333.jpg
# 1
# test/2339.jpg
# 1
# test/2349.jpg
# 1
# test/2356.jpg
# 1
# test/236.jpg
# 1
# test/2368.jpg
# 1
# test/2383.jpg
# 1
# test/2386.jpg
# 1
# test/2389.jpg
# 1
# test/2401.jpg
# 1
# test/2417.jpg
# 1
# test/2434.jpg
# 1
# test/2448.jpg
# 1
# test/2466.jpg
# 1
# test/2467.jpg
# 1
# test/2472.jpg
# 1
# test/2475.jpg
# 1
# test/2484.jpg
# 1
# test/250.jpg
# 1
# test/2506.jpg
# 1
# test/2507.jpg
# 1
# test/2519.jpg
# 1
# test/252.jpg
# 1
# test/2536.jpg
# 1
# test/2542.jpg
# 1
# test/2548.jpg
# 1
# test/2554.jpg
# 1
# test/2578.jpg
# 1
# test/2598.jpg
# 1
# test/2600.jpg
# 1
# test/2610.jpg
# 1
# test/2611.jpg
# 1
# test/2612.jpg
# 1
# test/2615.jpg
# 1
# test/2624.jpg
# 1
# test/2625.jpg
# 1
# test/2632.jpg
# 1
# test/265.jpg
# 1
# test/2650.jpg
# 1
# test/2662.jpg
# 1
# test/2663.jpg
# 1
# test/2665.jpg
# 1
# test/268.jpg
# 1
# test/2682.jpg
# 1
# test/27.jpg
# 1
# test/2708.jpg
# 1
# test/272.jpg
# 1
# test/2721.jpg
# 1
# test/2732.jpg
# 1
# test/2733.jpg
# 1
# test/2739.jpg
# 1
# test/2745.jpg
# 1
# test/2751.jpg
# 1
# test/2778.jpg
# 1
# test/2803.jpg
# 1
# test/2805.jpg
# 1
# test/2810.jpg
# 1
# test/2813.jpg
# 1
# test/2823.jpg
# 1
# test/283.jpg
# 1
# test/2833.jpg
# 1
# test/2835.jpg
# 1
# test/2838.jpg
# 1
# test/2846.jpg
# 1
# test/2855.jpg
# 1
# test/2864.jpg
# 1
# test/2869.jpg
# 1
# test/2887.jpg
# 1
# test/289.jpg
# 1
# test/2896.jpg
# 1
# test/2899.jpg
# 1
# test/2901.jpg
# 1
# test/2912.jpg
# 1
# test/2915.jpg
# 1
# test/2920.jpg
# 1
# test/2942.jpg
# 1
# test/2952.jpg
# 1
# test/2967.jpg
# 1
# test/2969.jpg
# 1
# test/2982.jpg
# 1
# test/2985.jpg
# 1
# test/2993.jpg
# 1
# test/3002.jpg
# 1
# test/3035.jpg
# 1
# test/3039.jpg
# 1
# test/3040.jpg
# 1
# test/3059.jpg
# 1
# test/3063.jpg
# 1
# test/3090.jpg
# 1
# test/3091.jpg
# 1
# test/3104.jpg
# 1
# test/312.jpg
# 1
# test/3154.jpg
# 1
# test/3168.jpg
# 1
# test/3173.jpg
# 1
# test/3202.jpg
# 1
# test/321.jpg
# 1
# test/3214.jpg
# 1
# test/3216.jpg
# 1
# test/3217.jpg
# 1
# test/3224.jpg
# 1
# test/3238.jpg
# 1
# test/3259.jpg
# 1
# test/3266.jpg
# 1
# test/327.jpg
# 1
# test/328.jpg
# 1
# test/3294.jpg
# 1
# test/3296.jpg
# 1
# test/3301.jpg
# 1
# test/3303.jpg
# 1
# test/3307.jpg
# 1
# test/3308.jpg
# 1
# test/3313.jpg
# 1
# test/3316.jpg
# 1
# test/3358.jpg
# 1
# test/3382.jpg
# 1
# test/3402.jpg
# 1
# test/3404.jpg
# 1
# test/3427.jpg
# 1
# test/3434.jpg
# 1
# test/3438.jpg
# 1
# test/3440.jpg
# 1
# test/345.jpg
# 1
# test/3459.jpg
# 1
# test/3483.jpg
# 1
# test/3494.jpg
# 1
# test/3503.jpg
# 1
# test/3520.jpg
# 1
# test/3527.jpg
# 1
# test/3528.jpg
# 1
# test/3536.jpg
# 1
# test/3543.jpg
# 1
# test/3546.jpg
# 1
# test/3550.jpg
# 1
# test/3551.jpg
# 1
# test/3569.jpg
# 1
# test/3574.jpg
# 1
# test/3576.jpg
# 1
# test/3578.jpg
# 1
# test/3591.jpg
# 1
# test/3626.jpg
# 1
# test/3629.jpg
# 1
# test/3636.jpg
# 1
# test/364.jpg
# 1
# test/3649.jpg
# 1
# test/3665.jpg
# 1
# test/3676.jpg
# 1
# test/3685.jpg
# 1
# test/3705.jpg
# 1
# test/3706.jpg
# 1
# test/3719.jpg
# 1
# test/3727.jpg
# 1
# test/3728.jpg
# 1
# test/3729.jpg
# 1
# test/3748.jpg
# 1
# test/375.jpg
# 1
# test/3753.jpg
# 1
# test/3754.jpg
# 1
# test/3767.jpg
# 1
# test/3772.jpg
# 1
# test/3780.jpg
# 1
# test/3791.jpg
# 1
# test/3797.jpg
# 1
# test/3799.jpg
# 1
# test/3803.jpg
# 1
# test/3804.jpg
# 1
# test/3807.jpg
# 1
# test/3830.jpg
# 1
# test/3834.jpg
# 1
# test/3843.jpg
# 1
# test/3844.jpg
# 1
# test/3872.jpg
# 1
# test/3882.jpg
# 1
# test/3885.jpg
# 1
# test/3894.jpg
# 1
# test/3904.jpg
# 1
# test/3910.jpg
# 1
# test/3914.jpg
# 1
# test/3927.jpg
# 1
# test/3936.jpg
# 1
# test/394.jpg
# 1
# test/3941.jpg
# 1
# test/3956.jpg
# 1
# test/3982.jpg
# 1
# test/3985.jpg
# 1
# test/4019.jpg
# 1
# test/4021.jpg
# 1
# test/4038.jpg
# 1
# test/4048.jpg
# 1
# test/4055.jpg
# 1
# test/4057.jpg
# 1
# test/4067.jpg
# 1
# test/407.jpg
# 1
# test/4075.jpg
# 1
# test/4098.jpg
# 1
# test/4100.jpg
# 1
# test/4110.jpg
# 1
# test/4111.jpg
# 1
# test/4118.jpg
# 1
# test/4119.jpg
# 1
# test/4128.jpg
# 1
# test/4132.jpg
# 1
# test/4143.jpg
# 1
# test/416.jpg
# 1
# test/4185.jpg
# 1
# test/4192.jpg
# 1
# test/4195.jpg
# 1
# test/4221.jpg
# 1
# test/4230.jpg
# 1
# test/4249.jpg
# 1
# test/4254.jpg
# 1
# test/4255.jpg
# 1
# test/4263.jpg
# 1
# test/4296.jpg
# 1
# test/4319.jpg
# 1
# test/432.jpg
# 1
# test/4343.jpg
# 1
# test/4346.jpg
# 1
# test/4367.jpg
# 1
# test/4388.jpg
# 1
# test/440.jpg
# 1
# test/4410.jpg
# 1
# test/4454.jpg
# 1
# test/4473.jpg
# 1
# test/4477.jpg
# 1
# test/4484.jpg
# 1
# test/4518.jpg
# 1
# test/4521.jpg
# 1
# test/454.jpg
# 1
# test/4557.jpg
# 1
# test/4567.jpg
# 1
# test/4569.jpg
# 1
# test/4576.jpg
# 1
# test/4582.jpg
# 1
# test/4585.jpg
# 1
# test/4592.jpg
# 1
# test/46.jpg
# 1
# test/4604.jpg
# 1
# test/4609.jpg
# 1
# test/4620.jpg
# 1
# test/4621.jpg
# 1
# test/4636.jpg
# 1
# test/4645.jpg
# 1
# test/4647.jpg
# 1
# test/4664.jpg
# 1
# test/4669.jpg
# 1
# test/4673.jpg
# 1
# test/4703.jpg
# 1
# test/4705.jpg
# 1
# test/4707.jpg
# 1
# test/4721.jpg
# 1
# test/4724.jpg
# 1
# test/4725.jpg
# 1
# test/4726.jpg
# 1
# test/4731.jpg
# 1
# test/4748.jpg
# 1
# test/4749.jpg
# 1
# test/4751.jpg
# 1
# test/4754.jpg
# 1
# test/4755.jpg
# 1
# test/477.jpg
# 1
# test/4780.jpg
# 1
# test/4786.jpg
# 1
# test/4787.jpg
# 1
# test/4810.jpg
# 1
# test/4823.jpg
# 1
# test/4828.jpg
# 1
# test/4829.jpg
# 1
# test/4833.jpg
# 1
# test/4834.jpg
# 1
# test/4840.jpg
# 1
# test/4843.jpg
# 1
# test/4851.jpg
# 1
# test/4852.jpg
# 1
# test/4872.jpg
# 1
# test/4879.jpg
# 1
# test/4885.jpg
# 1
# test/4930.jpg
# 1
# test/494.jpg
# 1
# test/4970.jpg
# 1
# test/4971.jpg
# 1
# test/4984.jpg
# 1
# test/4998.jpg
# 1
# test/5010.jpg
# 1
# test/5013.jpg
# 1
# test/5019.jpg
# 1
# test/5029.jpg
# 1
# test/5033.jpg
# 1
# test/5037.jpg
# 1
# test/5053.jpg
# 1
# test/5058.jpg
# 1
# test/506.jpg
# 1
# test/507.jpg
# 1
# test/509.jpg
# 1
# test/5095.jpg
# 1
# test/5097.jpg
# 1
# test/510.jpg
# 1
# test/5104.jpg
# 1
# test/5109.jpg
# 1
# test/512.jpg
# 1
# test/5131.jpg
# 1
# test/5137.jpg
# 1
# test/5145.jpg
# 1
# test/5151.jpg
# 1
# test/5152.jpg
# 1
# test/5158.jpg
# 1
# test/5160.jpg
# 1
# test/5161.jpg
# 1
# test/5162.jpg
# 1
# test/5168.jpg
# 1
# test/5174.jpg
# 1
# test/5198.jpg
# 1
# test/5209.jpg
# 1
# test/5226.jpg
# 1
# test/5231.jpg
# 1
# test/5233.jpg
# 1
# test/5235.jpg
# 1
# test/5240.jpg
# 1
# test/5266.jpg
# 1
# test/5276.jpg
# 1
# test/5284.jpg
# 1
# test/5286.jpg
# 1
# test/5291.jpg
# 1
# test/5294.jpg
# 1
# test/530.jpg
# 1
# test/5310.jpg
# 1
# test/5314.jpg
# 1
# test/5315.jpg
# 1
# test/5316.jpg
# 1
# test/5319.jpg
# 1
# test/5332.jpg
# 1
# test/5352.jpg
# 1
# test/5358.jpg
# 1
# test/537.jpg
# 1
# test/5372.jpg
# 1
# test/5373.jpg
# 1
# test/5379.jpg
# 1
# test/5381.jpg
# 1
# test/5383.jpg
# 1
# test/5392.jpg
# 1
# test/540.jpg
# 1
# test/5408.jpg
# 1
# test/5409.jpg
# 1
# test/5416.jpg
# 1
# test/546.jpg
# 1
# test/548.jpg
# 1
# test/556.jpg
# 1
# test/577.jpg
# 1
# test/582.jpg
# 1
# test/587.jpg
# 1
# test/588.jpg
# 1
# test/600.jpg
# 1
# test/621.jpg
# 1
# test/682.jpg
# 1
# test/684.jpg
# 1
# test/712.jpg
# 1
# test/735.jpg
# 1
# test/768.jpg
# 1
# test/780.jpg
# 1
# test/784.jpg
# 1
# test/787.jpg
# 1
# test/810.jpg
# 1
# test/816.jpg
# 1
# test/826.jpg
# 1
# test/84.jpg
# 1
# test/842.jpg
# 1
# test/845.jpg
# 1
# test/846.jpg
# 1
# test/848.jpg
# 1
# test/851.jpg
# 1
# test/883.jpg
# 1
# test/885.jpg
# 1
# test/891.jpg
# 1
# test/928.jpg
# 1
# test/931.jpg
# 1
# test/946.jpg
# 1
# test/95.jpg
# 1
# test/953.jpg
# 1
# test/971.jpg
# 1

# %%
# 根据生成识别文件的代码，自行编写main.py文件，要求文件可生成结果文件result.csv
# 已知的坑：main.py中需增加模型类的定义

# 测试main.py生成result.csv
# !python main.py
# 生成后自行验证
# Out:
# 1.0.0
# 0.2.1
# cpu
# 3578.jpg
# 5109.jpg
# 1409.jpg
# 2896.jpg
# 3550.jpg
# 2869.jpg
# 2855.jpg
# 1384.jpg
# 1810.jpg
# 3791.jpg
# 3168.jpg
# 3154.jpg
# 3626.jpg
# 1970.jpg
# 2289.jpg
# 5294.jpg
# 4834.jpg
# 1794.jpg
# 1582.jpg
# 4388.jpg
# 5097.jpg
# 2920.jpg
# 1540.jpg
# 4410.jpg
# 1781.jpg
# 1971.jpg
# 229.jpg
# 375.jpg
# 407.jpg
# 3753.jpg
# 3035.jpg
# 1178.jpg
# 1420.jpg
# 2129.jpg
# 3551.jpg
# 2103.jpg
# 2665.jpg
# 1422.jpg
# 2467.jpg
# 1608.jpg
# 2507.jpg
# 4604.jpg
# 1026.jpg
# 5240.jpg
# 203.jpg
# 4823.jpg
# 2739.jpg
# 3427.jpg
# 5095.jpg
# 1595.jpg
# 3382.jpg
# 1580.jpg
# 3803.jpg
# 2274.jpg
# 2506.jpg
# 1153.jpg
# 2466.jpg
# 2314.jpg
# 2472.jpg
# 3591.jpg
# 1351.jpg
# 5137.jpg
# 3546.jpg
# 4567.jpg
# 3224.jpg
# 170.jpg
# 3754.jpg
# 4749.jpg
# 5319.jpg
# 3797.jpg
# 2270.jpg
# 5286.jpg
# 3807.jpg
# 1976.jpg
# 548.jpg
# 5053.jpg
# 2066.jpg
# 4833.jpg
# 2339.jpg
# 4748.jpg
# 4984.jpg
# 1624.jpg
# 2846.jpg
# 4576.jpg
# 3543.jpg
# 2887.jpg
# 826.jpg
# 2663.jpg
# 3569.jpg
# 5332.jpg
# 4038.jpg
# 1140.jpg
# 2475.jpg
# 3780.jpg
# 1183.jpg
# 588.jpg
# 577.jpg
# 2298.jpg
# 5291.jpg
# 3804.jpg
# 2071.jpg
# 946.jpg
# 1587.jpg
# 1592.jpg
# 4367.jpg
# 953.jpg
# 1551.jpg
# 1545.jpg
# 3434.jpg
# 5284.jpg
# 210.jpg
# 1035.jpg
# 3636.jpg
# 416.jpg
# 364.jpg
# 2306.jpg
# 2448.jpg
# 600.jpg
# 2662.jpg
# 5131.jpg
# 2611.jpg
# 3527.jpg
# 883.jpg
# 3296.jpg
# 3719.jpg
# 2349.jpg
# 5383.jpg
# 4664.jpg
# 4843.jpg
# 2598.jpg
# 2942.jpg
# 712.jpg
# 1286.jpg
# 5037.jpg
# 4473.jpg
# 3308.jpg
# 1084.jpg
# 510.jpg
# 5235.jpg
# 5209.jpg
# 289.jpg
# 4705.jpg
# 2823.jpg
# 4249.jpg
# 2610.jpg
# 2176.jpg
# 17.jpg
# 4263.jpg
# 2612.jpg
# 2835.jpg
# 102.jpg
# 4707.jpg
# 4075.jpg
# 3040.jpg
# 328.jpg
# 2389.jpg
# 4673.jpg
# 3685.jpg
# 506.jpg
# 4840.jpg
# 512.jpg
# 2982.jpg
# 1521.jpg
# 2969.jpg
# 1284.jpg
# 1087.jpg
# 507.jpg
# 4128.jpg
# 4100.jpg
# 5381.jpg
# 3914.jpg
# 4048.jpg
# 3727.jpg
# 3294.jpg
# 842.jpg
# 5168.jpg
# 2161.jpg
# 2159.jpg
# 1336.jpg
# 846.jpg
# 891.jpg
# 885.jpg
# 5352.jpg
# 2401.jpg
# 5408.jpg
# 477.jpg
# 3910.jpg
# 3904.jpg
# 5226.jpg
# 4110.jpg
# 265.jpg
# 1929.jpg
# 4851.jpg
# 4879.jpg
# 2993.jpg
# 3483.jpg
# 5019.jpg
# 3440.jpg
# 4111.jpg
# 2548.jpg
# 5233.jpg
# 1690.jpg
# 4930.jpg
# 5409.jpg
# 4703.jpg
# 5151.jpg
# 3520.jpg
# 5145.jpg
# 3536.jpg
# 2600.jpg
# 845.jpg
# 851.jpg
# 104.jpg
# 2833.jpg
# 1645.jpg
# 5379.jpg
# 4067.jpg
# 5392.jpg
# 4098.jpg
# 312.jpg
# 3091.jpg
# 1876.jpg
# 4885.jpg
# 1057.jpg
# 5231.jpg
# 272.jpg
# 4852.jpg
# 1902.jpg
# 5033.jpg
# 931.jpg
# 4477.jpg
# 1269.jpg
# 3494.jpg
# 2952.jpg
# 2985.jpg
# 3872.jpg
# 1730.jpg
# 3090.jpg
# 2417.jpg
# 2615.jpg
# 5152.jpg
# 1334.jpg
# 4255.jpg
# 2624.jpg
# 4296.jpg
# 2803.jpg
# 4057.jpg
# 4731.jpg
# 4725.jpg
# 2368.jpg
# 2383.jpg
# 3894.jpg
# 4645.jpg
# 1715.jpg
# 3843.jpg
# 530.jpg
# 2036.jpg
# 2778.jpg
# 4484.jpg
# 3301.jpg
# 1502.jpg
# 928.jpg
# 2745.jpg
# 2751.jpg
# 3665.jpg
# 3936.jpg
# 1106.jpg
# 3705.jpg
# 3063.jpg
# 4724.jpg
# 5162.jpg
# 848.jpg
# 684.jpg
# 2625.jpg
# 4254.jpg
# 20.jpg
# 4518.jpg
# 5160.jpg
# 5174.jpg
# 4726.jpg
# 1689.jpg
# 321.jpg
# 1070.jpg
# 3459.jpg
# 3303.jpg
# 1500.jpg
# 1267.jpg
# 3316.jpg
# 5029.jpg
# 268.jpg
# 2578.jpg
# 283.jpg
# 4647.jpg
# 3882.jpg
# 3706.jpg
# 4055.jpg
# 2356.jpg
# 2183.jpg
# 5161.jpg
# 2632.jpg
# 1465.jpg
# 3266.jpg
# 3528.jpg
# 4521.jpg
# 2144.jpg
# 27.jpg
# 2805.jpg
# 5373.jpg
# 2434.jpg
# 3104.jpg
# 1075.jpg
# 3676.jpg
# 4119.jpg
# 2554.jpg
# 1908.jpg
# 250.jpg
# 735.jpg
# 4454.jpg
# 3313.jpg
# 5010.jpg
# 1510.jpg
# 3307.jpg
# 3844.jpg
# 537.jpg
# 4118.jpg
# 1706.jpg
# 1712.jpg
# 1869.jpg
# 3059.jpg
# 5372.jpg
# 494.jpg
# 2838.jpg
# 2810.jpg
# 5158.jpg
# 682.jpg
# 3503.jpg
# 1314.jpg
# 3259.jpg
# 125.jpg
# 5416.jpg
# 5358.jpg
# 3729.jpg
# 327.jpg
# 2386.jpg
# 3649.jpg
# 4132.jpg
# 3885.jpg
# 509.jpg
# 2033.jpg
# 2967.jpg
# 5013.jpg
# 4319.jpg
# 4872.jpg
# 252.jpg
# 2542.jpg
# 4669.jpg
# 3927.jpg
# 454.jpg
# 440.jpg
# 3728.jpg
# 1881.jpg
# 4721.jpg
# 5198.jpg
# 2813.jpg
# 816.jpg
# 3217.jpg
# 95.jpg
# 157.jpg
# 5316.jpg
# 3767.jpg
# 2519.jpg
# 5276.jpg
# 3834.jpg
# 4829.jpg
# 2733.jpg
# 1560.jpg
# 2901.jpg
# 2915.jpg
# 787.jpg
# 3404.jpg
# 2040.jpg
# 3438.jpg
# 4343.jpg
# 2732.jpg
# 546.jpg
# 4828.jpg
# 432.jpg
# 1818.jpg
# 3941.jpg
# 3799.jpg
# 3772.jpg
# 1617.jpg
# 4021.jpg
# 3982.jpg
# 4592.jpg
# 3216.jpg
# 195.jpg
# 3202.jpg
# 1429.jpg
# 4221.jpg
# 2650.jpg
# 3214.jpg
# 168.jpg
# 4751.jpg
# 5315.jpg
# 3002.jpg
# 4786.jpg
# 1832.jpg
# 4143.jpg
# 1985.jpg
# 587.jpg
# 1952.jpg
# 222.jpg
# 236.jpg
# 1577.jpg
# 2080.jpg
# 784.jpg
# 2043.jpg
# 4195.jpg
# 2484.jpg
# 4787.jpg
# 3956.jpg
# 5314.jpg
# 394.jpg
# 4585.jpg
# 196.jpg
# 810.jpg
# 2899.jpg
# 4230.jpg
# 2682.jpg
# 1162.jpg
# 5310.jpg
# 4998.jpg
# 4754.jpg
# 3985.jpg
# 1189.jpg
# 582.jpg
# 3173.jpg
# 2251.jpg
# 4620.jpg
# 3629.jpg
# 1957.jpg
# 4185.jpg
# 1572.jpg
# 780.jpg
# 1200.jpg
# 2721.jpg
# 2912.jpg
# 1599.jpg
# 971.jpg
# 3358.jpg
# 2708.jpg
# 3402.jpg
# 540.jpg
# 226.jpg
# 4621.jpg
# 2536.jpg
# 2244.jpg
# 1765.jpg
# 4609.jpg
# 4755.jpg
# 3748.jpg
# 1639.jpg
# 3238.jpg
# 4557.jpg
# 3576.jpg
# 4569.jpg
# 3574.jpg
# 191.jpg
# 84.jpg
# 4582.jpg
# 4019.jpg
# 4970.jpg
# 1834.jpg
# 4780.jpg
# 1820.jpg
# 1015.jpg
# 556.jpg
# 224.jpg
# 4810.jpg
# 1954.jpg
# 4192.jpg
# 2093.jpg
# 768.jpg
# 4346.jpg
# 5058.jpg
# 3830.jpg
# 4636.jpg
# 1982.jpg
# 5266.jpg
# 345.jpg
# 4971.jpg
# 2333.jpg
# 1148.jpg
# 3039.jpg
# 147.jpg
# 621.jpg
# 2864.jpg
# 46.jpg
# 5104.jpg
# finish
